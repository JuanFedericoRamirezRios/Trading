# %%
# !python --version
# Out:
# Python 3.10.18

# %% [markdown]
# Python 3.10

# %%
import nasdaqdatalink as nd
import confidentialData

# %%
nd.ApiConfig.api_key = confidentialData.ObtainNasdaqApiKey() # confidentialData.ObtainNasdaqApiKey() -> API key is in your profile.
